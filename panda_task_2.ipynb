# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("online_retail_II.csv")

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
#Cleaning and preprocessing the data to remove duplicates, missing values, and other errors.

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2010 8:26   2.55      17850.0  United Kingdom
# 1  12/1/2010 8:26   3.39      17850.0  United Kingdom
# 2  12/1/2010 8:26   2.75      17850.0  United Kingdom
# 3  12/1/2010 8:26   3.39      17850.0  United Kingdom
# 4  12/1/2010 8:26   3.39      17850.0  United Kingdom

# %%
df.drop("StockCode",axis=1,inplace=True)

# %%
df
# Out:
#        Invoice                          Description  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 541905  581587         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587                              POSTAGE         1
#
#             InvoiceDate  Price  Customer ID         Country
# 0        12/1/2010 8:26   2.55      17850.0  United Kingdom
# 1        12/1/2010 8:26   3.39      17850.0  United Kingdom
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.fillna(0, inplace=True)

# %%
#Merging and aggregating the data to create summary tables and metrics, such as total sales by product or customer.

# %%
df["Total_sales"] = df["Quantity"] * df["Price"]

# %%
# # Total sales by product
# product_sales = df.groupby('Description')['Price'].sum().sort_values(ascending=False)

# # Total sales by customer
# customer_sales = df.groupby('Customer ID')['Price'].sum().sort_values(ascending=False)

# %%
df
# Out:
#        Invoice                          Description  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 541905  581587         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587                              POSTAGE         1
#
#             InvoiceDate  Price  Customer ID         Country  Total_sales
# 0        12/1/2010 8:26   2.55      17850.0  United Kingdom        15.30
# 1        12/1/2010 8:26   3.39      17850.0  United Kingdom        20.34
# ...

# %%
#Analyzing the data to identify trends and patterns in customer purchase behavior, 
#such as which products are frequently purchased together, which products are popular at different times of year,
#or which customers are most valuable to the business.

# %%
#which products are frequently purchased together,
product_pairs = df.groupby(['Customer ID', 'Description'])['Price'].count()

# %%
product_pairs
# Out:
# Customer ID  Description
# 12346.0      MEDIUM CERAMIC TOP STORAGE JAR       2
# 12347.0      3D DOG PICTURE PLAYING CARDS         5
#              3D SHEET OF CAT STICKERS             1
#              3D SHEET OF DOG STICKERS             1
#              60 TEATIME FAIRY CAKE CASES          3
#                                                  ..
# 18287.0      STAR T-LIGHT HOLDER WILLIE WINKIE    1
#              STRAWBERRY BATH SPONGE               1
#              STRAWBERRY CERAMIC TRINKET BOX       1
#              SWISS CHALET TREE DECORATION         2
#              TREE T-LIGHT HOLDER WILLIE WINKIE    1
# Name: Price, Length: 269157, dtype: int64

# %%
#which products are popular at different times of year,
df['year'] = pd.DatetimeIndex(df['InvoiceDate']).year
product_sales_by_year = df.groupby(['Description', 'year'])['Price'].sum()

# %%
product_sales_by_year
# Out:
# Description                       year
#  4 PURPLE FLOCK DINNER CANDLES    2010      5.10
#                                   2011     80.45
#  50'S CHRISTMAS GIFT BAG LARGE    2011    137.29
#  DOLLY GIRL BEAKER                2011    170.40
#  I LOVE LONDON MINI BACKPACK      2011    285.55
#                                            ...
# ZINC TOP  2 DOOR WOODEN SHELF     2011    135.60
# ZINC WILLIE WINKIE  CANDLE STICK  2010      9.35
#                                   2011    158.14
# ZINC WIRE KITCHEN ORGANISER       2011     86.10
# ZINC WIRE SWEETHEART LETTER TRAY  2011     69.08
# Name: Price, Length: 6229, dtype: float64

# %%
#which customers are most valuable to the business.
customer_sales = df.groupby('Customer ID')['Price'].sum()

# %%
customer_sales
# Out:
# Customer ID
# 12346.0       2.08
# 12347.0     481.21
# 12348.0     178.71
# 12349.0     605.10
# 12350.0      65.30
#             ...
# 18280.0      47.65
# 18281.0      39.36
# 18282.0      62.68
# 18283.0    1174.33
# 18287.0     104.55
# Name: Price, Length: 4372, dtype: float64

# %%
#Creating visualizations to help communicate the results of your analysis, such as scatter plots
for Description, data in df.groupby('Description'):
    plt.scatter(data['InvoiceDate'], data['Price'], label=Description)

plt.xlabel('Invoice Date')
plt.ylabel('Price')
plt.title('Purchase product by Date')

plt.show()
